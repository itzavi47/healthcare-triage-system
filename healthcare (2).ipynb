# %%
# !pip install -q google-genai

from google import genai
import json
import re
import kaggle_secrets

# Load Gemini API key from Kaggle Secrets
GEMINI_API_KEY = kaggle_secrets.UserSecretsClient().get_secret("GEMINI_API_KEY")

# Initialize client
client = genai.Client(api_key=GEMINI_API_KEY)

print("API Loaded Successfully")
# Out:
# API Loaded Successfully

# %%
def ask_gemini(prompt, model="gemini-2.5-flash-lite"):
    try:
        response = client.models.generate_content(
            model=model,
            contents=prompt
        )
        return response.text
    except Exception as e:
        return f"Error: {str(e)}"

# %%
def medical_ai(user_text):
    
    # STEP 1: Extract symptoms
    symptom_prompt = f"""
    Extract only medical symptoms from this text:
    "{user_text}"
    Return them as a Python list with lowercase names.
    Do not add extra text.
    """
    raw = ask_gemini(symptom_prompt)
    try:
        symptoms = eval(raw)
    except:
        symptoms = []
    
    # STEP 2: Disease Prediction
    disease_prompt = f"""
    Based on symptoms {symptoms}, predict possible illnesses.
    Give 1–3 possibilities max.
    Keep them short, like: ["viral fever", "flu"].
    """
    try:
        diseases = eval(ask_gemini(disease_prompt))
    except:
        diseases = ["Not enough data"]
    
    # STEP 3: Risk Level
    risk_prompt = f"""
    Symptoms: {symptoms}
    Determine a risk level: Low, Medium, or High.
    Rules:
    - breathlessness, chest pain → High
    - fever + cough + fatigue → Medium
    - mild symptoms → Low
    
    Output only one word: "Low", "Medium", or "High".
    """
    risk = ask_gemini(risk_prompt).replace("\n","")
    
    # STEP 4: Doctor Guidance
    doctor_prompt = f"""
    Based on symptoms {symptoms} and risk "{risk}", 
    write:
    - when they must see a doctor
    - emergency warning signs
    
    Keep it short.
    """
    doctor_advice = ask_gemini(doctor_prompt)
    
    # STEP 5: Home Remedies
    remedies_prompt = f"""
    Provide safe home remedies for symptoms {symptoms}.
    No dangerous or prescription drugs.
    """
    remedies = ask_gemini(remedies_prompt)
    
    # STEP 6: OTC Medicines (Safe Only)
    otc_prompt = f"""
    Based on symptoms {symptoms}, give safe OTC options.
    Rules:
    - paracetamol for fever/pain
    - ORS for dehydration
    - cough lozenges for sore throat
    - No antibiotics
    - No prescription drugs
    """
    otc = ask_gemini(otc_prompt)

    # FINAL STRUCTURED OUTPUT
    return {
        "symptoms_detected": symptoms,
        "possible_diseases": diseases,
        "risk_level": risk,
        "doctor_guidance": doctor_advice,
        "home_remedies": remedies,
        "safe_otc": otc
    }

# %%
user_input = "I have fever for two days, slight cough, and I feel very tired."
medical_ai(user_input)
# Out:
# {'symptoms_detected': ['fever', 'cough', 'tired'],
#  'possible_diseases': ['common cold', 'flu', 'bronchitis'],
#  'risk_level': 'Medium',
#  'doctor_guidance': "**When to see a doctor:**\n\n*   Symptoms don't improve after a week or worsen.\n*   High fever persists.\n\n**Emergency warning signs:**\n\n*   Difficulty breathing\n*   Chest pain\n*   Confusion",
#  'home_remedies': "Here are some safe home remedies for fever, cough, and tiredness. Remember, these are for symptom relief. If your symptoms are severe, persistent, or you have underlying health conditions, it's always best to consult a doctor.\n\n## Home Remedies for Fever:\n\nFever is your body's way of fighting infection, so the goal is to help your body do this comfortably.\n\n*   **Hydration is Key:**\n    *   **Water:** Drink plenty of plain water throughout the day.\n    *   **Herbal Teas:** Warm, caffeine-free herbal teas like chamomile, peppermint, or ginger tea can be soothing and help with hydration. Add a spoonful of honey (for adults and children over 1 year old) for its potential soothing properties.\n    *   **Broths/Soups:** Clear broths like chicken or vegetable soup provide fluids and electrolytes.\n    *   **Diluted Juices:** Fruit juices diluted with water can also be a good option, but avoid overly sugary drinks.\n\n*   **Rest:**\n    *   **Prioritize Sleep:** Allow your body to focus its energy on healing. Get as much sleep as possible.\n    *   **Light Activity:** Avoid strenuous activities. If you need to move around, do so gently.\n\n*   **Cooling Measures (Use with Caution):**\n    *   **Lukewarm Bath or Sponge Bath:** A lukewarm (not cold) bath or sponging your skin with lukewarm water can help to gently lower body temperature. Avoid cold water, as this can cause shivering, which can actually increase body temperature.\n    *   **Light Clothing and Bedding:** Wear lightweight, breathable clothing and use light blankets. Avoid bundling up, which can trap heat.\n    *   **Cool Compress:** A cool (not cold) damp cloth placed on your forehead or neck can provide comfort.\n\n*   **Nutritious Foods:**\n    *   **Light and Easy to Digest:** Focus on bland, easily digestible foods like toast, rice, applesauce, and bananas.\n\n**Important Note on Fever:** While these remedies can help manage the discomfort of a fever, if you have a very high fever (generally above 103°F or 39.4°C for adults, or consult your pediatrician for child-specific guidelines), or if the fever is accompanied by other concerning symptoms like a stiff neck, rash, or difficulty breathing, seek medical attention.\n\n## Home Remedies for Cough:\n\nCoughing helps clear mucus from your airways. These remedies aim to soothe your throat and reduce irritation.\n\n*   **Honey:**\n    *   **Directly:** A spoonful of honey (for adults and children over 1 year old) can coat the throat and provide relief.\n    *   **In Warm Drinks:** Mix honey into warm water or herbal tea.\n\n*   **Saltwater Gargle:**\n    *   **Preparation:** Dissolve 1/4 to 1/2 teaspoon of salt in a glass of warm water.\n    *   **How to:** Gargle with the solution several times a day. This can help soothe a sore throat and loosen mucus.\n\n*   **Steam Inhalation:**\n    *   **Method:** Take a hot shower or bath, or lean over a bowl of hot (not boiling) water with a towel draped over your head to create a steam tent. Inhale the steam deeply. You can add a few drops of eucalyptus or peppermint essential oil to the water (ensure good ventilation and avoid if you have respiratory sensitivities or asthma).\n    *   **Benefits:** Steam can help to moisten airways and loosen congestion.\n\n*   **Herbal Teas:**\n    *   **Soothing Options:** Chamomile, ginger, licorice root, and marshmallow root teas can be beneficial for coughs.\n\n*   **Humidifier:**\n    *   **Use:** A cool-mist humidifier in your bedroom can help keep the air moist, which can soothe irritated airways and loosen mucus.\n\n*   **Elevate Your Head:**\n    *   **Sleep:** Prop yourself up with extra pillows when sleeping to help with drainage and reduce coughing.\n\n*   **Ginger:**\n    *   **In Drinks:** Fresh ginger steeped in hot water can have anti-inflammatory properties.\n\n**Important Note on Cough:** If your cough is persistent, producing thick colored mucus, or accompanied by shortness of breath, chest pain, or  ...
#  'safe_otc': "Here are some safe Over-The-Counter (OTC) options for symptoms of fever, cough, and tiredness:\n\n*   **For Fever:** **Paracetamol** (also known as acetaminophen) is a good choice for reducing fever and relieving any associated aches.\n\n*   **For Cough:**\n    *   **Cough drops or lozenges** can help soothe a sore throat and ease coughing.\n    *   **Honey** can also be an effective natural remedy for cough. (Note: Do not give honey to children under 1 year old).\n\n*   **For Tiredness:** Rest is the most important thing. OTC medications do not directly treat tiredness from illness, but addressing the fever can help you feel more comfortable and potentially improve rest.\n\n*   **For Hydration:** If you are experiencing any symptoms that might lead to dehydration (like a very high fever, though not explicitly listed), **Oral Rehydration Salts (ORS)** are recommended to help replenish fluids and electrolytes.\n\n**Important Considerations:**\n\n*   Always follow the dosage instructions on the product packaging.\n*   If your symptoms worsen, do not improve after a few days, or if you develop new symptoms, it's important to consult a healthcare professional.\n*   This advice is for general OTC options and does not substitute professional medical advice."}

# %%
# Test Module for Medical AI
test_cases = [
    "I have fever, body pain and headache since morning.",
    "My throat is hurting and I have a dry cough.",
    "I feel weakness, dizziness and no appetite.",
    "Severe chest pain and shortness of breath.",
    "Runny nose and mild cough for two days."
]

for i, case in enumerate(test_cases, 1):
    print(f"\n--- TEST {i} ---")
    print("Input:", case)
    output = medical_ai(case)
    print("Output:", output)
# Out:
# --- TEST 1 ---
# Input: I have fever, body pain and headache since morning.
# Output: {'symptoms_detected': ['fever', 'body pain', 'headache'], 'possible_diseases': ['viral fever', 'flu', 'common cold'], 'risk_level': 'Low', 'doctor_guidance': '**See a doctor if:**\n*   Symptoms persist for more than 3 days or worsen.\n\n**Emergency warning signs:**\n*   Severe headache, stiff neck, or rash.\n*   Difficulty breathing.\n*   Confusion or extreme drowsiness.\n*   Persistent vomiting.', 'home_remedies': "It's important to remember that home remedies are for **mild symptoms** and can help provide comfort. If your fever is high, persistent, or accompanied by severe pain, it's crucial to **consult a doctor**.\n\nHere are some safe home remedies for fever, body pain, and headache:\n\n**For Fever and Body Pain:**\n\n*   **Rest:** This is paramount. Your body needs energy to fight off whatever is causing the fever and pain. Stay in bed or on the couch and avoid strenuous activities.\n*   **Hydration is Key:**\n    *   **Water:** Drink plenty of plain water. This helps your body regulate temperature and can flush out toxins.\n    *   **Clear Broths/Soups:** Chicken or vegetable broth can provide fluids and electrolytes, which are beneficial when you're sick.\n    *   **Herbal Teas:** Warm (not hot) herbal teas can be soothing.\n        *   **Chamomile:** Known for its calming and anti-inflammatory properties.\n        *   **Ginger Tea:** Can help with inflammation and nausea, and its warmth can be comforting. You can make it by steeping fresh ginger slices in hot water.\n        *   **Peppermint Tea:** Can be refreshing and may help with mild discomfort.\n    *   **Electrolyte Drinks (Diluted):** If you're having trouble keeping fluids down or have experienced vomiting/diarrhea, a diluted electrolyte drink can help replenish lost nutrients.\n*   **Cool Compresses:**\n    *   **Lukewarm Sponge Bath:** Gently sponge your body with lukewarm water. Avoid cold water, as this can cause shivering, which raises body temperature. Focus on the forehead, neck, and underarms.\n    *   **Cool Cloth on Forehead:** A cool, damp washcloth on your forehead can provide temporary relief from feverish feelings and headache.\n*   **Light Clothing and Blankets:** Don't overdress or bundle up excessively. Wear light, breathable clothing. Use a light blanket. You want to allow your body to release heat. If you feel chilled, a light blanket is fine, but remove it if you start to feel warm.\n*   **Humidifier:** Running a humidifier in your room can help keep nasal passages moist, which can be more comfortable if you have a stuffy nose along with your symptoms.\n\n**For Headache:**\n\n*   **Hydration:** As mentioned above, dehydration can worsen headaches. Ensure you're drinking plenty of fluids.\n*   **Rest in a Dark, Quiet Room:** Bright lights and loud noises can aggravate headaches. Try to lie down in a dimly lit, quiet space.\n*   **Gentle Scalp Massage:** Lightly massaging your temples, forehead, and the back of your neck can sometimes help relieve tension headaches.\n*   **Cool or Warm Compress:** Some people find a cool compress on their forehead or eyes soothing, while others prefer a warm compress on the back of their neck. Experiment to see what works best for you.\n*   **Peppermint Oil (Diluted):** A very small amount of diluted peppermint oil (mixed with a carrier oil like coconut oil) can be gently massaged onto the temples. **Be very careful not to get it in your eyes.**\n\n**Important Considerations and When to Seek Medical Advice:**\n\n*   **Fever Temperature:** For adults, a fever is generally considered 100.4°F (38°C) or higher. For children, the threshold is lower and varies by age.\n*   **When to Call a Doctor:**\n    *   **High Fever:** If your fever is very high (e.g., over 103°F or 39.4°C for adults) and doesn't come down with home remedies.\n    *   **Persistent Fever:** If the fever lasts for more than 2-3 days.\n    *   **Severe Pain:** If the body pain or headache is intense and debilitating.\n    *   **Other Sym ...
#
# --- TEST 2 ---
# Input: My throat is hurting and I have a dry cough.
# Output: {'symptoms_detected': ['sore throat', 'dry cough'], 'possible_diseases': ['common cold', 'flu', 'strep throat'], 'risk_level': 'Low', 'doctor_guidance': "**When to see a doctor:**\n\n* Symptoms worsen or don't improve after 7-10 days.\n* Fever develops.\n\n**Emergency Warning Signs:**\n\n* Difficulty breathing\n* Chest pain\n* High fever that doesn't break\n* Blue lips or face", 'home_remedies': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 50.154500773s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '50s'}]}}", 'safe_otc': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 49.993998457s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '49s'}]}}"}
#
# --- TEST 3 ---
# Input: I feel weakness, dizziness and no appetite.
# Output: {'symptoms_detected': [], 'possible_diseases': ['Not enough data'], 'risk_level': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 49.677923056s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '49s'}]}}", 'doctor_guidance': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 49.603232442s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '49s'}]}}", 'home_remedies': 'Please provide the symptoms you\'d like home remedies for! I can then offer safe, non-prescription suggestions.\n\nThe more specific you are, the better I can tailor the advice. For example, instead of just "pain," you could say "sore throat," "headache," or "muscle ache."\n\nOnce you give me the symptoms, I\'ll provide you with safe home remedies.', 'safe_otc': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 48.777029425s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '48s'}]}}"}
#
# --- TEST 4 ---
# Input: Severe chest pain and shortness of breath.
# Output: {'symptoms_detected': [], 'possible_diseases': ['Not enough data'], 'risk_level': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 48.486228572s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '48s'}]}}", 'doctor_guidance': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 48.330800437s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '48s'}]}}", 'home_remedies': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 48.26076082s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '48s'}]}}", 'safe_otc': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 48.193414265 ...
#
# --- TEST 5 ---
# Input: Runny nose and mild cough for two days.
# Output: {'symptoms_detected': [], 'possible_diseases': ['Not enough data'], 'risk_level': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 47.305182044s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '47s'}]}}", 'doctor_guidance': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 47.125228326s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '47s'}]}}", 'home_remedies': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 47.055511091s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '47s'}]}}", 'safe_otc': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 46.91254440 ...

# %%
# --- TEST 5 ---
input_text = "I have vomiting and stomach cramps since last night."
print("--- TEST 5 ---")
print("Input:", input_text)
print("Output:", medical_ai(input_text))
# Out:
# --- TEST 5 ---
# Input: I have vomiting and stomach cramps since last night.
# Output: {'symptoms_detected': [], 'possible_diseases': ['Not enough data'], 'risk_level': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 46.576174742s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '46s'}]}}", 'doctor_guidance': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 46.516130633s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '46s'}]}}", 'home_remedies': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 46.371546097s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '46s'}]}}", 'safe_otc': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 46.28219230 ...

# %%
def reminder_agent(analysis_output):
    """
    Generates short, AI-agent style reminders for:
    - Medication timing
    - Doctor visit timing
    """

    # --- Medication Reminder ---
    med_prompt = f"""
    Symptoms: {analysis_output.get("symptoms_detected")}
    OTC advice: {analysis_output.get("safe_otc")}

    Create a VERY SHORT medication reminder.
    Rules:
    - If no OTC medicine or only 'paracetamol' → say "Take only if needed"
    - If medicine exists → include simple timing (every 6–8 hours)
    - Output format: {{"medicine": "...", "timing": "..."}}
    - Keep it super short.
    """
    med = ask_gemini(med_prompt)

    # --- Doctor Visit Reminder ---
    doc_prompt = f"""
    Risk: {analysis_output.get("risk_level")}
    Doctor guidance: {analysis_output.get("doctor_guidance")}

    Write a short reminder for when the patient should see a doctor.
    Output 1 short sentence only.
    """
    doc = ask_gemini(doc_prompt)

    return {
        "medication_reminder": med,
        "doctor_visit_reminder": doc
    }

# %%
result = medical_ai("I have fever and body pain")
reminders = reminder_agent(result)
result, reminders
# Out:
# ({'symptoms_detected': [],
#   'possible_diseases': ['Not enough data'],
#   'risk_level': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 45.934477969s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '45s'}]}}",
#   'doctor_guidance': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 45.868404552s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '45s'}]}}",
#   'home_remedies': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 45.754561626s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '45s'}]}}",
#   'safe_otc': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 45.684306714s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '45s'}]}}"},
#  {'medication_reminder': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 45.622108566s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '45s'}]}}",
#   'doctor_visit_reminder': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 45.472712404s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '45s'}]}}"})

# %%
def full_health_agent(user_text):
    analysis = medical_ai(user_text)
    reminders = reminder_agent(analysis)

    # Merge in one clean JSON
    return {
        **analysis,
        "medication_reminder": reminders.get("medication_reminder"),
        "doctor_visit_reminder": reminders.get("doctor_visit_reminder")
    }

# %%
full_health_agent("I have fever and body pain")
# Out:
# {'symptoms_detected': [],
#  'possible_diseases': ['Not enough data'],
#  'risk_level': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 45.133257653s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '45s'}]}}",
#  'doctor_guidance': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 45.06103617s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '45s'}]}}",
#  'home_remedies': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 44.993357434s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '44s'}]}}",
#  'safe_otc': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 44.917956228s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '44s'}]}}",
#  'medication_reminder': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 44.78926251s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '44s'}]}}",
#  'doctor_visit_reminder': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 44.692650956s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '44s'}]}}"}

# %%
def short_health_response(data):
    return {
        "symptoms_detected": data.get("symptoms_detected"),

        "possible_diseases": data.get("possible_diseases"),

        "risk_level": data.get("risk_level"),

        "doctor_guidance": [
            "See a doctor if symptoms worsen or don't improve in 2–3 days.",
            "Go immediately if you have breathing issues, confusion, stiff neck, or severe headache."
        ],

        "home_remedies": [
            "Rest well and stay hydrated.",
            "Use paracetamol for fever/body pain.",
            "Use warm compress for body aches.",
            "Drink warm herbal tea (ginger/chamomile).",
            "Use light clothing and keep room ventilated."
        ],

        "safe_otc": [
            "Paracetamol for fever/body pain.",
            "ORS for dehydration.",
            "Cough lozenges if throat irritation."
        ],

        "medication_reminder": data.get("medication_reminder"),

        "doctor_visit_reminder": data.get("doctor_visit_reminder")
    }

# %% [markdown]
# **Here is the final agent which will give user whole details about his desease and also remind him to take medicine and see doctor**

# %%
raw = full_health_agent("I have fever and body pain")
short_health_response(raw)
# Out:
# {'symptoms_detected': [],
#  'possible_diseases': ['Not enough data'],
#  'risk_level': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 44.425667736s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '44s'}]}}",
#  'doctor_guidance': ["See a doctor if symptoms worsen or don't improve in 2–3 days.",
#   'Go immediately if you have breathing issues, confusion, stiff neck, or severe headache.'],
#  'home_remedies': ['Rest well and stay hydrated.',
#   'Use paracetamol for fever/body pain.',
#   'Use warm compress for body aches.',
#   'Drink warm herbal tea (ginger/chamomile).',
#   'Use light clothing and keep room ventilated.'],
#  'safe_otc': ['Paracetamol for fever/body pain.',
#   'ORS for dehydration.',
#   'Cough lozenges if throat irritation.'],
#  'medication_reminder': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 44.022641867s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '44s'}]}}",
#  'doctor_visit_reminder': "Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\\nPlease retry in 43.954290419s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '43s'}]}}"}
